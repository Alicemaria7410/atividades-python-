# %% [markdown]
# <a href="https://colab.research.google.com/github/Alicemaria7410/atividades-python-/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Atividade 01-Introduçao ao Python
print("Ola,mundo!")
print("Curso Tecnico em informatica")
# Out:
# Ola,mundo!
# Curso Tecnico em informatica

# %%
disciplina=input("Digite o nome da disciplina")
conteudo=input("Digite o conteudo estudado")
atividade=input("Digite o numero da atividade")
# Out:
# Digite o nome da disciplinaAlgoritimo e logica de programaçao
# Digite o conteudo estudadoPython
# Digite o numero da atividade01

# %%
print("\n---Informaçoes da atividade---")
print("Disciplina:",disciplina)
print("Conteudo:",conteudo)
print("Atividade:",atividade)
# Out:
# ---Informaçoes da atividade---
# Disciplina: Algoritimo e logica de programaçao
# Conteudo: Python
# Atividade: 01
